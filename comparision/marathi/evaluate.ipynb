# %%
import math

def precision_at_k(relevant, retrieved, k=1):
    retrieved = retrieved[:k]
    rel_set = set(relevant)
    return sum([1 for r in retrieved if r in rel_set]) / k


def recall_at_k(relevant, retrieved, k=10):
    rel_set = set(relevant)
    retrieved = retrieved[:k]
    return sum([1 for r in retrieved if r in rel_set]) / len(rel_set)


def mrr(relevant, retrieved):
    for idx, r in enumerate(retrieved, start=1):
        if r in relevant:
            return 1 / idx
    return 0

# %%
def f1_score(precision, recall):
    if precision + recall == 0:
        return 0
    return 2 * (precision * recall) / (precision + recall)

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch("http://localhost:9200",
                   basic_auth = ('elasticsearch', 'e3TKzHmKRFWBP4gY--cjeQ'),
                   request_timeout=60,
                   )
es.ping() 
print(es.info())
# Out:
# {'name': 'LAPTOP-ANN0J427', 'cluster_name': 'elasticsearch', 'cluster_uuid': '6AxnonBCTU-8fGsKa_EYMQ', 'version': {'number': '9.1.3', 'build_flavor': 'default', 'build_type': 'zip', 'build_hash': '0c781091a2f57de895a73a1391ff8426c0153c8d', 'build_date': '2025-08-24T22:05:04.526302670Z', 'build_snapshot': False, 'lucene_version': '10.2.2', 'minimum_wire_compatibility_version': '8.19.0', 'minimum_index_compatibility_version': '8.0.0'}, 'tagline': 'You Know, for Search'}

# %%
# Lexical Search

def lexical_search(index_name, query_text, k=10):
    body = {
        "size": k,
        "query": {
            "multi_match": {
                "query": query_text,
                "fields": ["scheme_name", "description"]
            }
        }
    }
    res = es.search(index=index_name, body=body)
    return [int(hit["_source"]["scheme_id"]) for hit in res["hits"]["hits"]]


print("Lexical search function ready ✅")
# Out:
# Lexical search function ready ✅

# %% [markdown]
# ### mahasbert

# %%
def semantic_search(index_name, query_text, model, k=10):
    query_vec = model.encode(query_text).tolist()

    body = {
        "size": k,
        "query": {
            "script_score": {
                "query": {"match_all": {}},
                "script": {
                    "source": "cosineSimilarity(params.qv, 'mahasbert_des_vector') + 1.0",
                    "params": {"qv": query_vec}
                }
            }
        }
    }

    
    res = es.search(index=index_name, body=body)
    return [int(hit["_source"]["scheme_id"]) for hit in res["hits"]["hits"]]

# %%
def hybrid_search(index_name, query_text, model, k=10, alpha=0.5):
    query_vec = model.encode(query_text).tolist()

    body = {
        "size": k,
        "query": {
            "bool": {
                "should": [
                    {
                        "multi_match": {
                            "query": query_text,
                            "fields": ["scheme_name^2", "description"]
                        }
                    },
                    {
                        "script_score": {
                            "query": {"match_all": {}},
                            "script": {
                                "source":
                                    "double bm25=_score; "
                                    "double vec=cosineSimilarity(params.qv, 'mahasbert_des_vector') + 1.0; "
                                    "return bm25*(1-params.alpha) + vec*params.alpha;",
                                "params": {
                                    "qv": query_vec,
                                    "alpha": alpha
                                }
                            }
                        }
                    }
                ]
            }
        }
    }

    
    res = es.search(index=index_name, body=body)
    return [int(hit['_source']['scheme_id']) for hit in res['hits']['hits']]

# %% [markdown]
# ### indicsbert

# %%
def semantic_search(index_name, query_text, model, k=10):
    query_vec = model.encode(query_text).tolist()

    body = {
        "size": k,
        "query": {
            "script_score": {
                "query": {"match_all": {}},
                "script": {
                    "source": "cosineSimilarity(params.qv, 'indicsbert_des_vector') + 1.0",
                    "params": {"qv": query_vec}
                }
            }
        }
    }

    
    res = es.search(index=index_name, body=body)
    return [int(hit["_source"]["scheme_id"]) for hit in res["hits"]["hits"]]

# %%
def hybrid_search(index_name, query_text, model, k=10, alpha=0.5):
    query_vec = model.encode(query_text).tolist()

    body = {
        "size": k,
        "query": {
            "bool": {
                "should": [
                    {
                        "multi_match": {
                            "query": query_text,
                            "fields": ["scheme_name^2", "description"]
                        }
                    },
                    {
                        "script_score": {
                            "query": {"match_all": {}},
                            "script": {
                                "source":
                                    "double bm25=_score; "
                                    "double vec=cosineSimilarity(params.qv, 'indicsbert_des_vector') + 1.0; "
                                    "return bm25*(1-params.alpha) + vec*params.alpha;",
                                "params": {
                                    "qv": query_vec,
                                    "alpha": alpha
                                }
                            }
                        }
                    }
                ]
            }
        }
    }

    
    res = es.search(index=index_name, body=body)
    return [int(hit['_source']['scheme_id']) for hit in res['hits']['hits']]

# %%
import pandas as pd
test_marathi = pd.read_csv("../testSets/marathi.csv")
print("Test set loaded ✅")
# Out:
# Test set loaded ✅

# %%
import pandas as pd

def evaluate(model_name, model, test_df, index_name,query_col="query",relevant_col="relevant_scheme_ids") :
    
    results = []

    for _, row in test_df.iterrows():
        query = row[query_col]
        raw = row[relevant_col]

        # Remove brackets and spaces
        clean = raw.strip().replace("[", "").replace("]", "").replace(" ", "")

        # Handle empty case
        if clean == "":
            relevant = []
        else:
            relevant = list(map(int, clean.split(",")))

        # Run searches
        lex_res = lexical_search(index_name, query)
        sem_res = semantic_search(index_name, query, model)
        hyb_res = hybrid_search(index_name, query, model)

        # Collect results for all 3 search types
        for search_type, retrieved in [
            ("lexical", lex_res),
            ("semantic", sem_res),
            ("hybrid", hyb_res)
        ]:
            results.append({
                "model": model_name,
                "search_type": search_type,
                "query": query,
                "relevant_count": len(relevant),
                "precision": precision_at_k(relevant, retrieved),
                "recall": recall_at_k(relevant, retrieved),
                "mrr": mrr(relevant, retrieved)
            })

    return pd.DataFrame(results)

# %%
from loadModels import load_mahaSBERT

mahaSBERT_model = load_mahaSBERT()
print("mahaSBERT model loaded ✅")

df_maha = evaluate(
    model_name="mahaSBERT",
    model=mahaSBERT_model,
    test_df=test_marathi,
    index_name="marathi",
    query_col="query",
    relevant_col="relevant_scheme_ids",
)
# Out:
# mahaSBERT model loaded ✅

# %%
df_maha
# Out:
#          model search_type                                         query  \
# 0    mahaSBERT     lexical  शेतकऱ्यांसाठी अन्नधान्याऐवजी रोख रक्कम योजना
# 1    mahaSBERT    semantic  शेतकऱ्यांसाठी अन्नधान्याऐवजी रोख रक्कम योजना
# 2    mahaSBERT      hybrid  शेतकऱ्यांसाठी अन्नधान्याऐवजी रोख रक्कम योजना
# 3    mahaSBERT     lexical       सवलतीच्या दरात भोजन उपलब्ध करणारी योजना
# 4    mahaSBERT    semantic       सवलतीच्या दरात भोजन उपलब्ध करणारी योजना
# ..         ...         ...                                           ...
# 214  mahaSBERT    semantic                           कृषी पणन मंडळ योजना
# 215  mahaSBERT      hybrid                           कृषी पणन मंडळ योजना
# 216  mahaSBERT     lexical                     आपलसरकार पोर्टलवरील योजना
# 217  mahaSBERT    semantic                     आपलसरकार पोर्टलवरील योजना
# 218  mahaSBERT      hybrid                     आपलसरकार पोर्टलवरील योजना
#
#      relevant_count  precision    recall       mrr
# 0                 1        1.0  1.000000  1.000000
# 1                 1        0.0  1.000000  0.500000
# 2                 1        1.0  1.000000  1.000000
# 3                 1        1.0  1.000000  1.000000
# 4                 1        1.0  1.000000  1.000000
# ..              ...        ...       ...       ...
# 214               4        1.0  1.000000  1.000000
# 215               4        0.0  1.000000  0.333333
# 216              56        1.0  0.053571  1.000000
# 217              56        1.0  0.107143  1.000000
# 218              56        1.0  0.053571  1.000000
#
# [219 rows x 7 columns]

# %%
df_maha["f1"] = df_maha.apply(lambda row: f1_score(row["precision"], row["recall"]), axis=1)

# %%
from loadModels import load_indicSBERT
indicSBERT_model = load_indicSBERT()
print("indicSBERT model loaded ✅")

df_indic = evaluate(
    model_name="indicSBERT",
    model=indicSBERT_model,
    test_df=test_marathi,
    index_name="marathi",
    query_col="query",
    relevant_col="relevant_scheme_ids"
)
# Out:
# indicSBERT model loaded ✅

# %%
df_indic
# Out:
#           model search_type                                         query  \
# 0    indicSBERT     lexical  शेतकऱ्यांसाठी अन्नधान्याऐवजी रोख रक्कम योजना
# 1    indicSBERT    semantic  शेतकऱ्यांसाठी अन्नधान्याऐवजी रोख रक्कम योजना
# 2    indicSBERT      hybrid  शेतकऱ्यांसाठी अन्नधान्याऐवजी रोख रक्कम योजना
# 3    indicSBERT     lexical       सवलतीच्या दरात भोजन उपलब्ध करणारी योजना
# 4    indicSBERT    semantic       सवलतीच्या दरात भोजन उपलब्ध करणारी योजना
# ..          ...         ...                                           ...
# 214  indicSBERT    semantic                           कृषी पणन मंडळ योजना
# 215  indicSBERT      hybrid                           कृषी पणन मंडळ योजना
# 216  indicSBERT     lexical                     आपलसरकार पोर्टलवरील योजना
# 217  indicSBERT    semantic                     आपलसरकार पोर्टलवरील योजना
# 218  indicSBERT      hybrid                     आपलसरकार पोर्टलवरील योजना
#
#      relevant_count  precision    recall       mrr
# 0                 1        1.0  1.000000  1.000000
# 1                 1        0.0  1.000000  0.500000
# 2                 1        1.0  1.000000  1.000000
# 3                 1        1.0  1.000000  1.000000
# 4                 1        1.0  1.000000  1.000000
# ..              ...        ...       ...       ...
# 214               4        1.0  0.750000  1.000000
# 215               4        0.0  1.000000  0.333333
# 216              56        1.0  0.053571  1.000000
# 217              56        1.0  0.142857  1.000000
# 218              56        1.0  0.053571  1.000000
#
# [219 rows x 7 columns]

# %% [markdown]
# ## final comparision

# %%
df_indic["f1"] = df_indic.apply(lambda row: f1_score(row["precision"], row["recall"]), axis=1)

# %%
combined = pd.concat([df_maha, df_indic], ignore_index=True)

# %%
summary = combined.groupby(["model", "search_type"]).agg({
    "precision": "mean",
    "recall": "mean",
    "mrr": "mean",
    "f1": "mean"
}).reset_index()

# %%
summary
# Out:
#         model search_type  precision    recall       mrr        f1
# 0  indicSBERT      hybrid   0.863014  0.952789  0.904925  0.850708
# 1  indicSBERT     lexical   0.808219  0.942058  0.879811  0.793957
# 2  indicSBERT    semantic   0.520548  0.775930  0.623989  0.500098
# 3   mahaSBERT      hybrid   0.863014  0.966487  0.906295  0.850708
# 4   mahaSBERT     lexical   0.808219  0.942058  0.879811  0.793957
# 5   mahaSBERT    semantic   0.643836  0.782290  0.712785  0.624569

# %%
overall = combined.groupby("model").agg({
    "precision": "mean",
    "recall": "mean",
    "mrr": "mean"
})
print(overall)
# Out:
#             precision    recall       mrr
# model
# indicSBERT   0.730594  0.890259  0.802908
# mahaSBERT    0.771689  0.896945  0.832964
